# %%
import mne

# %%
file_path = "derivatives/sub-001/eeg/sub-001_task-eyesclosed_eeg.set" 
raw = mne.io.read_raw_eeglab(file_path, preload=True)

print(raw.info)

raw.plot()
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, T5, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  dig: 22 items (3 Cardinal, 19 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
file_path = "derivatives/sub-002/eeg/sub-002_task-eyesclosed_eeg.set" 
raw = mne.io.read_raw_eeglab(file_path, preload=True)

print(raw.info)

raw.plot()
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, T5, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  dig: 22 items (3 Cardinal, 19 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import pandas as pd

data, times = raw.get_data(), raw.times 
 
df = pd.DataFrame(data.T, columns=raw.ch_names)
df
# Out:
#              Fp1       Fp2        F3        F4        C3        C4        P3  \
# 0      -0.000014 -0.000013 -0.000013 -0.000015 -0.000014 -0.000014 -0.000013
# 1      -0.000011 -0.000011 -0.000011 -0.000013 -0.000013 -0.000012 -0.000012
# 2      -0.000010 -0.000011 -0.000010 -0.000010 -0.000011 -0.000011 -0.000012
# 3      -0.000009 -0.000011 -0.000010 -0.000008 -0.000011 -0.000011 -0.000013
# 4      -0.000008 -0.000013 -0.000010 -0.000007 -0.000012 -0.000011 -0.000015
# ...          ...       ...       ...       ...       ...       ...       ...
# 396545 -0.000004 -0.000008 -0.000005 -0.000007 -0.000006 -0.000006 -0.000009
# 396546 -0.000004 -0.000006 -0.000005 -0.000005 -0.000005 -0.000005 -0.000007
# 396547 -0.000004 -0.000004 -0.000005 -0.000003 -0.000005 -0.000005 -0.000006
# 396548 -0.000005 -0.000004 -0.000007 -0.000003 -0.000006 -0.000006 -0.000005
# 396549 -0.000007 -0.000004 -0.000010 -0.000004 -0.000008 -0.000008 -0.000006
#
#               P4        O1        O2        F7            F8        T3  \
# 0      -0.000012 -0.000011 -0.000016 -0.000009 -1.171983e-05 -0.000009
# 1      -0.000010 -0.000009 -0.000015 -0.000007 -1.008915e-05 -0.000009
# 2      -0.000010 -0.000009 -0.000014 -0.000006 -9.643548e-06 -0.000009
# 3      -0.000010 -0.000010 -0.000014 -0.000007 -1.047517e-05 -0.000012
# 4      -0.000011 -0.000012 -0.000016 -0.000008 -1.235484e-05 -0.000015
# ...          ...       ...       ...       ...           ...       ...
# 396545 -0.000008 -0.000009 -0.000012 -0.000005 -2.705928e-06 -0.000004
# 396546 -0.000006 -0.000007 -0.000009 -0.000005 -9.878463e-07 -0.000003
# 396547 -0.000005 -0.000005 -0.000007 -0.000005  2.396657e-07 -0.000003
# 396548 -0.000005 -0.000005 -0.000007 -0.000006  8.112128e-07 -0.000004
# 396549 -0.000006 -0.000006 -0.000007 -0.000007  6.704350e-07 -0.000006
#
#                   T4        T5            T6        Fz        Cz        Pz
# 0      -6.309359e-06 -0.000011 -7.522885e-06 -0.000016 -0.000015 -0.000012
# 1      -5.919376e-06 -0.000009 -5.622316e-06 -0.000014 -0.000013 -0.000010
# 2      -6.802406e-06 -0.000009 -4.885856e-06 -0.000012 -0.000012 -0.000009
# 3      -8.884608e-06 -0.000011 -5.338573e-06 -0.000011 -0.000011 -0.000009
# 4      -1.178896e-05 -0.000013 -6.705518e-06 -0.000011 -0.000012 -0.000010
# ...              ...       ...           ...       ...       ...       ...
# 396545 -3.746986e-06 -0.000005 -3.117009e-06 -0.000010 -0.000014 -0.000014
# 396546 -2.104878e-06 -0.000003 -9.413683e-07 -0.000008 -0.000012 -0.000011
# 396547 -9.669852e-07 -0.000003  3.359566e-07 -0.000008 -0.000011 -0.000009
# 396548 -4.744287e-07 -0.000003  6.535053e-07 -0.000008 -0.000010 -0.000008
# 396549 -6.549191e-07 -0.000004  1.105456e-07 -0.000009 -0.000011 -0.000009
#
# [396550 rows x 19 columns]
